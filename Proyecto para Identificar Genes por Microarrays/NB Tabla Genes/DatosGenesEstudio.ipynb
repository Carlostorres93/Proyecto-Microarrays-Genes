# %% [markdown]
# ### **Estudio de los genes**

# %%
#Libreria para trabajar en la API de la NCBI

pip install biopython
# Out:
# Requirement already satisfied: biopython in c:\users\angel\anaconda3\lib\site-packages (1.83)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\angel\anaconda3\lib\site-packages (from biopython) (1.24.3)

# %%
#No correr este código. Este código se usó para consultar en la API de la NCBI si el gen existe, para resolver dudas puntuales.

from Bio import Entrez
import pandas as pd

# Especificar un e-mail para la web de NCBI
Entrez.email = "angel_g_dominguez@hotmail.com"

def informacion_gen(nombre_gen):
    handle = Entrez.esearch(db="gene", term=nombre_gen)
    record = Entrez.read(handle)
    gene_id = record["IdList"][0]  # Con esto se halla el ID del gen que aparece en primer lugar
    handle = Entrez.esummary(db="gene", id=gene_id)
    summary = Entrez.read(handle)
    return summary

nombre_gen = "TFAP2B"  
datos_gen = informacion_gen(nombre_gen)
print(datos_gen)
# Out:
# {'DocumentSummarySet': DictElement({'DocumentSummary': [DictElement({'Name': 'TP53', 'Description': 'tumor protein p53', 'Status': '0', 'CurrentID': '0', 'Chromosome': '17', 'GeneticSource': 'genomic', 'MapLocation': '17p13.1', 'OtherAliases': 'BCC7, BMFS5, LFS1, P53, TRP53', 'OtherDesignations': 'cellular tumor antigen p53|antigen NY-CO-13|mutant tumor protein 53|phosphoprotein p53|transformation-related protein 53|tumor protein 53|tumor supressor p53', 'NomenclatureSymbol': 'TP53', 'NomenclatureName': 'tumor protein p53', 'NomenclatureStatus': 'Official', 'Mim': ['191170'], 'GenomicInfo': [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420', 'ExonCount': '13'}], 'GeneWeight': '938340', 'Summary': 'This gene encodes a tumor suppressor protein containing transcriptional activation, DNA binding, and oligomerization domains. The encoded protein responds to diverse cellular stresses to regulate expression of target genes, thereby inducing cell cycle arrest, apoptosis, senescence, DNA repair, or changes in metabolism. Mutations in this gene are associated with a variety of human cancers, including hereditary cancers such as Li-Fraumeni syndrome. Alternative splicing of this gene and the use of alternate promoters result in multiple transcript variants and isoforms. Additional isoforms have also been shown to result from the use of alternate translation initiation codons from identical transcript variants (PMIDs: 12032546, 20937277). [provided by RefSeq, Dec 2016]', 'ChrSort': '17', 'ChrStart': '7668420', 'Organism': {'ScientificName': 'Homo sapiens', 'CommonName': 'human', 'TaxID': '9606'}, 'LocationHist': [{'AnnotationRelease': 'RS_2023_10', 'AssemblyAccVer': 'GCF_000001405.40', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420'}, {'AnnotationRelease': 'RS_2023_10', 'AssemblyAccVer': 'GCF_009914755.1', 'ChrAccVer': 'NC_060941.1', 'ChrStart': '7591593', 'ChrStop': '7572543'}, {'AnnotationRelease': 'RS_2023_03', 'AssemblyAccVer': 'GCF_000001405.40', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420'}, {'AnnotationRelease': 'RS_2023_03', 'AssemblyAccVer': 'GCF_009914755.1', 'ChrAccVer': 'NC_060941.1', 'ChrStart': '7591593', 'ChrStop': '7572543'}, {'AnnotationRelease': '110', 'AssemblyAccVer': 'GCF_000001405.40', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420'}, {'AnnotationRelease': '110', 'AssemblyAccVer': 'GCF_009914755.1', 'ChrAccVer': 'NC_060941.1', 'ChrStart': '7591593', 'ChrStop': '7572543'}, {'AnnotationRelease': '109.20211119', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420'}, {'AnnotationRelease': '109.20210514', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420'}, {'AnnotationRelease': '109.20210226', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420'}, {'AnnotationRelease': '109.20201120', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687489', 'ChrStop': '7668420'}, {'AnnotationRelease': '109.20200815', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687549', 'ChrStop': '7668401'}, {'AnnotationRelease': '109.20200522', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687549', 'ChrStop': '7668401'}, {'AnnotationRelease': '109.20200228', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687549', 'ChrStop': '7668401'}, {'AnnotationRelease': '109.20191205', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687549', 'ChrStop': '7668401'}, {'AnnotationRelease': '109.20190905', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_000017.11', 'ChrStart': '7687549', 'ChrStop': '7668401'}, {'AnnotationRelease': '109.20190607', 'AssemblyAccVer': 'GCF_000001405.39', 'ChrAccVer': 'NC_00001 ...

# %%
# Se continua con la obtención de una tabla que nos de información específica de cada gen. Para ello, se carga el archivo con los genes de interés.

df = pd.read_excel("microarrays-genes.xlsx")

# %%
df
# Out:
#                         type     Gen
# 0               1553394_a_at    TP53
# 1                 1553434_at  CYP4Z1
# 2                 1553602_at   ERBB2
# 3               1555745_a_at    TP53
# 4               1555778_a_at   VEGFA
# ..                       ...     ...
# 130              240304_s_at   EP300
# 131                242579_at     APP
# 132                243241_at    TP53
# 133                 37892_at    TP53
# 134  AFFX-HUMRGE/M10098_5_at    TP53
#
# [135 rows x 2 columns]

# %%
# %%time

#Se itera y por cada gen se realiza una consulta en la API de la NCBI para obtener información de interés de cara a tomar decisiones
#relativas a genes implicados en procesos tumorales. El objetivo es generar una tabla con los datos de la NCBI para una posterior
#investigación bibliográfica

from Bio import Entrez
import pandas as pd

# SE especifica un e-mail para la web de NCBI
Entrez.email = "angel_g_dominguez@hotmail.com"

def informacion_gen(nombre_gen):
    handle = Entrez.esearch(db="gene", term=nombre_gen)
    record = Entrez.read(handle)
    if record["IdList"]:  # Se verifica si encontramos resultados en la API
        gene_id = record["IdList"][0]  # Devuelve el ID del gen encontrado
        handle = Entrez.esummary(db="gene", id=gene_id)
        summary = Entrez.read(handle)
        return summary
    else:
        print(f"No se encontró información para el gen: {nombre_gen}") #Si no encuentra un gen, devuelve el mensaje
        return None

# Leer el DataFrame con los nombres de los genes
df_genes = pd.read_excel("microarrays-genes.xlsx")  

# Lista para almacenar la información de los genes
informacion_genes = []

# Iterar sobre los nombres de los genes en el DataFrame
for nombre_gen in df_genes["Gen"]:
    datos_gen = informacion_gen(nombre_gen)
    if datos_gen:
        informacion_genes.append(datos_gen)

# Convertir la lista de información de genes a DataFrame
df_informacion_genes = pd.json_normalize([x["DocumentSummarySet"]["DocumentSummary"][0] for x in informacion_genes])


# Guardar la información en un archivo CSV
df_informacion_genes.to_csv("informacion_genes.csv", index=False)

df_informacion_genes
# Out:
# CPU times: total: 55.8 s
# Wall time: 6min 7s
#              Name                                    Description Status  \
# 0    LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 1           NR3C1  nuclear receptor subfamily 3 group C member 1      0
# 2            TP53                              tumor protein p53      0
# 3    LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 4            TP53                              tumor protein p53      0
# ..            ...                                            ...    ...
# 130          TP53                              tumor protein p53      0
# 131          TP53                              tumor protein p53      0
# 132  LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 133  LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 134  LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
#
#     CurrentID Chromosome GeneticSource MapLocation  \
# 0           0         13       genomic
# 1           0          5       genomic      5q31.3
# 2           0         17       genomic     17p13.1
# 3           0         13       genomic
# 4           0         17       genomic     17p13.1
# ..        ...        ...           ...         ...
# 130         0         17       genomic     17p13.1
# 131         0         17       genomic     17p13.1
# 132         0         13       genomic
# 133         0         13       genomic
# 134         0         13       genomic
#
#                       OtherAliases  \
# 0
# 1        GCCR, GCR, GCRST, GR, GRL
# 2    BCC7, BMFS5, LFS1, P53, TRP53
# 3
# 4    BCC7, BMFS5, LFS1, P53, TRP53
# ..                             ...
# 130  BCC7, BMFS5, LFS1, P53, TRP53
# 131  BCC7, BMFS5, LFS1, P53, TRP53
# 132
# 133
# 134
#
#                                      OtherDesignations NomenclatureSymbol  \
# 0         TP53-regulated inhibitor of apoptosis 1-like
# 1    glucocorticoid receptor|nuclear receptor subfa...              NR3C1
# 2    cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# 3         TP53-regulated inhibitor of apoptosis 1-like
# 4    cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# ..                                                 ...                ...
# 130  cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# 131  cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# 132       TP53-regulated inhibitor of apoptosis 1-like
# 133       TP53-regulated inhibitor of apoptosis 1-like
# 134       TP53-regulated inhibitor of apoptosis 1-like
#
#      ...       Mim                                        GenomicInfo  \
# 0    ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 1    ...  [138040]  [{'ChrLoc': '5', 'ChrAccVer': 'NC_000005.10', ...
# 2    ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# 3    ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 4    ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# ..   ...       ...                                                ...
# 130  ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# 131  ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# 132  ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 133  ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 134  ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
#
#     GeneWeight                                            Summary ChrSort  \
# 0            0                                                     ~~last
# 1       110260  This gene encodes glucocorticoid receptor, whi...      05
# 2       938340  This gene encodes a tumor suppressor protein c...      17
# 3            0                                                     ~~last
# 4       938340  This gene encodes a tumor suppressor protein c...      17
# ..         ...                                                ...     ...
# 130     938340  This gene encodes a tumor suppressor protein c...      17
# 131     938340  This gene encodes a tumor suppressor protein c...      17
# 132          0                                                     ~~last
# 133          0                                                     ~~last
# 134          0                                                     ~~last
#
#       ChrStart                                       LocationHist  \
# 0    999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 1    143277930  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 2      7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 3    999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 4      7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# ..         ...                                                ...
# 130    7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 131    7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 132  999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 133  999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 134  999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
#
#     Organism.ScientificName Organism.CommonName Organism.TaxID
# 0        Cydia fagiglandana                            1458189
# 1              Homo sapiens               human           9606
# 2              Homo sapiens               human           9606
# 3        Cydia fagiglandana                            1458189
# 4              Homo sapiens               human           9606
# ..                      ...                 ...            ...
# 130            Homo sapiens               human           9606
# 131            Homo sapiens               human           9606
# 132      Cydia fagiglandana                            1458189
# 133      Cydia fagiglandana                            1458189
# 134      Cydia fagiglandana                            1458189
#
# [135 rows x 22 columns]

# %%
df_infogenes = pd.read_csv("informacion_genes.csv")

# %%
pd.json_normalize(df_informacion_genes["GenomicInfo"].explode()) #Normalizamos para limpiar la estructura de algunas columnas
# Out:
#     ChrLoc     ChrAccVer   ChrStart    ChrStop ExonCount
# 0       13   NC_085944.1   12014682   12015583         2
# 1        5  NC_000005.10  143435511  143277930        15
# 2       17  NC_000017.11    7687489    7668420        13
# 3       13   NC_085944.1   12014682   12015583         2
# 4       17  NC_000017.11    7687489    7668420        13
# ..     ...           ...        ...        ...       ...
# 130     17  NC_000017.11    7687489    7668420        13
# 131     17  NC_000017.11    7687489    7668420        13
# 132     13   NC_085944.1   12014682   12015583         2
# 133     13   NC_085944.1   12014682   12015583         2
# 134     13   NC_085944.1   12014682   12015583         2
#
# [135 rows x 5 columns]

# %%
# Tabla final donde se puede encontrar en Summary información relativa si la hay, al igual que podemos hallar
# Obtener resultados en otros organismos implica que el estudio requiere de profundizar en cada apartado, encontrar estudios en
#humana, descartar genes de menor interés, comprobar compatibilidad en estudios de humana, etc... 

df_genes = pd.json_normalize([x["DocumentSummarySet"]["DocumentSummary"][0] for x in informacion_genes])

df_genes
# Out:
#              Name                                    Description Status  \
# 0    LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 1           NR3C1  nuclear receptor subfamily 3 group C member 1      0
# 2            TP53                              tumor protein p53      0
# 3    LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 4            TP53                              tumor protein p53      0
# ..            ...                                            ...    ...
# 130          TP53                              tumor protein p53      0
# 131          TP53                              tumor protein p53      0
# 132  LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 133  LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
# 134  LOC134670285   TP53-regulated inhibitor of apoptosis 1-like      0
#
#     CurrentID Chromosome GeneticSource MapLocation  \
# 0           0         13       genomic
# 1           0          5       genomic      5q31.3
# 2           0         17       genomic     17p13.1
# 3           0         13       genomic
# 4           0         17       genomic     17p13.1
# ..        ...        ...           ...         ...
# 130         0         17       genomic     17p13.1
# 131         0         17       genomic     17p13.1
# 132         0         13       genomic
# 133         0         13       genomic
# 134         0         13       genomic
#
#                       OtherAliases  \
# 0
# 1        GCCR, GCR, GCRST, GR, GRL
# 2    BCC7, BMFS5, LFS1, P53, TRP53
# 3
# 4    BCC7, BMFS5, LFS1, P53, TRP53
# ..                             ...
# 130  BCC7, BMFS5, LFS1, P53, TRP53
# 131  BCC7, BMFS5, LFS1, P53, TRP53
# 132
# 133
# 134
#
#                                      OtherDesignations NomenclatureSymbol  \
# 0         TP53-regulated inhibitor of apoptosis 1-like
# 1    glucocorticoid receptor|nuclear receptor subfa...              NR3C1
# 2    cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# 3         TP53-regulated inhibitor of apoptosis 1-like
# 4    cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# ..                                                 ...                ...
# 130  cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# 131  cellular tumor antigen p53|antigen NY-CO-13|mu...               TP53
# 132       TP53-regulated inhibitor of apoptosis 1-like
# 133       TP53-regulated inhibitor of apoptosis 1-like
# 134       TP53-regulated inhibitor of apoptosis 1-like
#
#      ...       Mim                                        GenomicInfo  \
# 0    ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 1    ...  [138040]  [{'ChrLoc': '5', 'ChrAccVer': 'NC_000005.10', ...
# 2    ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# 3    ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 4    ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# ..   ...       ...                                                ...
# 130  ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# 131  ...  [191170]  [{'ChrLoc': '17', 'ChrAccVer': 'NC_000017.11',...
# 132  ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 133  ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
# 134  ...        []  [{'ChrLoc': '13', 'ChrAccVer': 'NC_085944.1', ...
#
#     GeneWeight                                            Summary ChrSort  \
# 0            0                                                     ~~last
# 1       110260  This gene encodes glucocorticoid receptor, whi...      05
# 2       938340  This gene encodes a tumor suppressor protein c...      17
# 3            0                                                     ~~last
# 4       938340  This gene encodes a tumor suppressor protein c...      17
# ..         ...                                                ...     ...
# 130     938340  This gene encodes a tumor suppressor protein c...      17
# 131     938340  This gene encodes a tumor suppressor protein c...      17
# 132          0                                                     ~~last
# 133          0                                                     ~~last
# 134          0                                                     ~~last
#
#       ChrStart                                       LocationHist  \
# 0    999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 1    143277930  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 2      7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 3    999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 4      7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# ..         ...                                                ...
# 130    7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 131    7668420  [{'AnnotationRelease': 'RS_2023_10', 'Assembly...
# 132  999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 133  999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
# 134  999999999  [{'AnnotationRelease': 'RS_2024_02', 'Assembly...
#
#     Organism.ScientificName Organism.CommonName Organism.TaxID
# 0        Cydia fagiglandana                            1458189
# 1              Homo sapiens               human           9606
# 2              Homo sapiens               human           9606
# 3        Cydia fagiglandana                            1458189
# 4              Homo sapiens               human           9606
# ..                      ...                 ...            ...
# 130            Homo sapiens               human           9606
# 131            Homo sapiens               human           9606
# 132      Cydia fagiglandana                            1458189
# 133      Cydia fagiglandana                            1458189
# 134      Cydia fagiglandana                            1458189
#
# [135 rows x 22 columns]
